# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# %%
# Path to the NetCDF file
fileinput = '/data/IMFSE/PythonCourse/CDS/CERRA/cerra-2012.nc'
# Open the dataset
ds = xr.open_dataset(fileinput)
# Coordinates of the center of the burned area
burned_area_lat = 41.709377863541654
burned_area_lon = 1.892273844304144

# %%
# 2. Calculate the nearest grid point indices
abs_diff_lat = np.abs(ds.latitude[:,0].values - burned_area_lat)
abs_diff_lon = np.abs(ds.longitude[0,:].values - burned_area_lon)
# Find the index of the nearest grid point
lat_idx = abs_diff_lat.argmin().item()
lon_idx = abs_diff_lon.argmin().item()

# %%
ds.latitude[:,0].values
# Out:
# array([20.292281  , 20.33366508, 20.37505942, ..., 63.70871082,
#        63.73913522, 63.76951353])

# %%
lat_idx, lon_idx
# Out:
# (499, 411)

# %%
da = ds.isel(x=lon_idx,y=lat_idx)[['si10','t2m']]
july_data = ds.sel(valid_time=ds.valid_time.dt.month == 7)))[['si10','t2m']]
# Out:
#   Cell In[6], line 2
#     july_data = ds.sel(valid_time=ds.valid_time.dt.month == 7)))[['si10','t2m']]
#                                                               ^
# SyntaxError: unmatched ')'

# %%
da['t2m'].plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 da['t2m'].plot()
#
# NameError: name 'da' is not defined

# %%
# Now select data only for July using the 'valid_time' and filter for July
july_data = ds.sel(valid_time=ds.valid_time.dt.month == 7)
# Extract wind speed values for July at the nearest grid point
july_wind_speed_at_point = july_data.isel(x=lon_idx, y=lat_idx)
# Plot July data at the nearest grid point
july_wind_speed_at_point.si10.plot()
plt.title("Wind Speed for July at Nearest Grid Point")
plt.show()

# %%
july_wind_speed_at_point
# Out:
# <xarray.Dataset> Size: 5kB
# Dimensions:     (valid_time: 124)
# Coordinates:
#   * valid_time  (valid_time) datetime64[ns] 992B 2012-07-01 ... 2012-07-31T18...
#     latitude    float64 8B ...
#     longitude   float64 8B ...
#     expver      (valid_time) <U4 2kB ...
# Data variables:
#     wdir10      (valid_time) float32 496B ...
#     si10        (valid_time) float32 496B ...
#     r2          (valid_time) float32 496B ...
#     t2m         (valid_time) float32 496B ...
# Attributes:
#     GRIB_centre:             eswi
#     GRIB_centreDescription:  Norrkoping
#     GRIB_subCentre:          255
#     Conventions:             CF-1.7
#     institution:             Norrkoping
#     history:                 2024-08-13T09:20 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
july_wind_speed_at_point.to_dataframe()
# Out:
#                      latitude  longitude expver      wdir10      si10  \
# valid_time
# 2012-07-01 00:00:00  47.89917  -1.090566   prod  250.586044  4.126287
# 2012-07-01 06:00:00  47.89917  -1.090566   prod  235.554764  2.786541
# 2012-07-01 12:00:00  47.89917  -1.090566   prod  248.391022  3.700498
# 2012-07-01 18:00:00  47.89917  -1.090566   prod  251.109741  4.288396
# 2012-07-02 00:00:00  47.89917  -1.090566   prod  223.171906  2.139348
# ...                       ...        ...    ...         ...       ...
# 2012-07-30 18:00:00  47.89917  -1.090566   prod  155.711243  1.977325
# 2012-07-31 00:00:00  47.89917  -1.090566   prod  236.031326  2.312461
# 2012-07-31 06:00:00  47.89917  -1.090566   prod  203.219269  2.432274
# 2012-07-31 12:00:00  47.89917  -1.090566   prod  223.312653  3.842819
# 2012-07-31 18:00:00  47.89917  -1.090566   prod  246.461334  2.500313
#
#                             r2         t2m
# valid_time
# 2012-07-01 00:00:00  86.394524  285.066986
# 2012-07-01 06:00:00  87.596268  285.095551
# 2012-07-01 12:00:00  44.061646  292.590607
# 2012-07-01 18:00:00  58.662899  291.227264
# 2012-07-02 00:00:00  91.779404  284.702484
# ...                        ...         ...
# 2012-07-30 18:00:00  50.198738  293.000519
# 2012-07-31 00:00:00  88.080681  287.228668
# 2012-07-31 06:00:00  89.382812  286.569885
# 2012-07-31 12:00:00  49.714668  296.193115
# 2012-07-31 18:00:00  44.201172  297.864136
#
# [124 rows x 7 columns]
